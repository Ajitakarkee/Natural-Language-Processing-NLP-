# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajitakarkee/Natural-Language-Processing-NLP-/blob/main/Lab_4_Machine_translation_eng_Hindi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers sentencepiece torch

# %%
from huggingface_hub import login
login()

# %%
from transformers import MarianMTModel, MarianTokenizer

# Use the English to Nepali translation model
model_name = "Helsinki-NLP/opus-mt-en-hi"
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
# Load the tokenizer and model
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/812k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/306M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
def translate_to_nepali(text):
    # Tokenize input
    inputs = tokenizer(text, return_tensors="pt", padding=True)

    # Generate translation
    translated = model.generate(**inputs)

    # Decode output
    hindi_text = tokenizer.decode(translated[0], skip_special_tokens=True)
    return hindi_text

# %%
# Example usage
english_text = "A sudden idea can sometimes lead to the most unexpected and interesting discoveries."
hindi_translation = translate_to_nepali(english_text)

# %%
print("English:", english_text)
print("hindi:", hindi_translation)
# Out:
# English: A sudden idea can sometimes lead to the most unexpected and interesting discoveries.
# hindi: अचानक विचार कभी - कभी सबसे अप्रत्याशित और दिलचस्प खोजों की ओर ले जा सकता है ।

# %% [markdown]
# Performed by: Ajita Karki
#
# Roll.no: 07
