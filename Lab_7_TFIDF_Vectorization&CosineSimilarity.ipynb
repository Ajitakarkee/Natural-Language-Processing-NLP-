# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajitakarkee/Natural-Language-Processing-NLP-/blob/main/Lab_7_TFIDF_Vectorization%26CosineSimilarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TFIDF_Vectorization&CosineSimilarity**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Example documents
Doc1 = "Python is a popular programming language."
Doc2 = "Data science uses Python for analysis and machine learning."

# %%
# List of documents
documents = [Doc1, Doc2]

# %%
# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer()

# %%
# Fit the vectorizer to documents and transform the documents
tfidf_vectors = vectorizer.fit_transform(documents)

# %%
# Print the vocabulary (terms)
print("Vocabulary (terms):")
print(vectorizer.get_feature_names_out())
# Out:
# Vocabulary (terms):
# ['analysis' 'and' 'data' 'for' 'is' 'language' 'learning' 'machine'
#  'popular' 'programming' 'python' 'science' 'uses']

# %%
# Print TF-IDF vectors for each document
print("\nTF-IDF Vectors:")
for i, doc in enumerate(documents):
    print(f"Document {i + 1}:")
    print(tfidf_vectors[i])
    print()
# Out:
# TF-IDF Vectors:
# Document 1:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5 stored elements and shape (1, 13)>
#   Coords	Values
#   (0, 10)	0.33517574332792605
#   (0, 4)	0.47107781233161794
#   (0, 8)	0.47107781233161794
#   (0, 9)	0.47107781233161794
#   (0, 5)	0.47107781233161794
#
# Document 2:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9 stored elements and shape (1, 13)>
#   Coords	Values
#   (0, 10)	0.24395572500006343
#   (0, 2)	0.3428712594108198
#   (0, 11)	0.3428712594108198
#   (0, 12)	0.3428712594108198
#   (0, 3)	0.3428712594108198
#   (0, 0)	0.3428712594108198
#   (0, 1)	0.3428712594108198
#   (0, 7)	0.3428712594108198
#   (0, 6)	0.3428712594108198

# %%
#import cosine_similarity
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity between the documents
cosine_sim = cosine_similarity(tfidf_vectors[0], tfidf_vectors[1]).flatten()[0]

# Print cosine similarity
print(f"Cosine Similarity between document 1 and document 2: {cosine_sim}")
# Out:
# Cosine Similarity between document 1 and document 2: 0.08176804146599938
